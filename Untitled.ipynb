# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Data/Real-Data/real_2013.csv')

# %%
df['PM 2.5'].plot()
# Out:
# <AxesSubplot:>

# %%
df['T'].plot()
# Out:
# <AxesSubplot:>

# %%
df['H'].plot()
# Out:
# <AxesSubplot:>
